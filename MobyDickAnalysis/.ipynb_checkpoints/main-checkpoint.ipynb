# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# # Assignment 2 - Introduction to NLTK
#
# In part 1 of this assignment you will use nltk to explore the Herman Melville novel Moby Dick. Then in part 2 you will create a spelling recommender function that uses nltk to find words similar to the misspelling.

# %% [markdown]
# ## Part 1 - Analyzing Moby Dick

# %%
import nltk
import pandas as pd
import numpy as np

from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 15})

nltk.download('popular')

nltk.download('nps_chat')

nltk.download('webtext')

from nltk.book import *

# If you would like to work with the raw text you can use 'moby_raw'
with open('moby.txt', 'r') as f:
    moby_raw = f.read()
    
# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# ...

# %% [markdown]
# ### Example 1
#
# How many tokens (words and punctuation symbols) are in text1?
#
# *This function should return an integer.*

# %%
def example_one():
    
    return len(nltk.word_tokenize(moby_raw)) # or alternatively len(text1)

example_one()
# Out:
# 255038

# %% [markdown]
# ### Example 2
#
# How many unique tokens (unique words and punctuation) does text1 have?
#
# *This function should return an integer.*

# %%
def example_two():
    
    return len(set(nltk.word_tokenize(moby_raw))) # or alternatively len(set(text1))

example_two()
# Out:
# 20742

# %% [markdown]
# ### Example 3
#
# After lemmatizing the verbs, how many unique tokens does text1 have?
#
# *This function should return an integer.*

# %%
from nltk.stem import WordNetLemmatizer

def example_three():

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]

    return len(set(lemmatized))

example_three()
# Out:
# 16887

# %% [markdown]
# ### Question 1
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
#
# *This function should return a float.*

# %%
def answer_one():
    
    alltokens = example_one() 
    uniquetokens = example_two()
    
    return uniquetokens/alltokens

answer_one()
# Out:
# 0.08132905684643073

# %% [markdown]
# ### Question 2
#
# What percentage of tokens is 'whale'or 'Whale'?
#
# *This function should return a float.*

# %%
def answer_two():
    
    alltokens = nltk.word_tokenize(moby_raw)
    
    count1 = alltokens.count('whale')
    count2 = alltokens.count('Whale')
    
    return (count1+count2)*100/len(alltokens)


answer_two()
# Out:
# 0.4124875508747716

# %% [markdown]
# ### Question 3
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
#
# *This function should return a list of 20 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
def answer_three():
    
    liste = (nltk.word_tokenize(moby_raw))
    xar = []
    res = FreqDist(liste)
    son  = {k: v for k, v in sorted(res.items(), key=lambda item: item[1], reverse = True)}
    
    for x in list(son)[0:20]:
        
        y= (x,son[x])
        
        xar.append(y)

    return xar

answer_three()
# Out:
# [(',', 19204),
#  ('the', 13715),
#  ('.', 7306),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2978),
#  ('his', 2459),
#  ('it', 2196),
#  ('I', 2113),
#  ('!', 1767),
#  ('is', 1722),
#  ('--', 1713),
#  ('with', 1659),
#  ('he', 1658),
#  ('was', 1639),
#  ('as', 1620)]

# %% [markdown]
# ### Question 4
#
# What tokens have a length of greater than 5 and frequency of more than 150?
#
# *This function should return an alphabetically sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def answer_four():
    liste = (nltk.word_tokenize(moby_raw))
    xar = []
    res = FreqDist(liste)
    son  = {k: v for k, v in sorted(res.items(), key=lambda item: item[1], reverse = True)}
    bu = son.keys()
    freqwords = [w for w in bu if len(w) > 5 and res[w] > 150]
    
    #freqwords = [x.lower() for x in freqwords]
    result = sorted(freqwords)
    
    return result

answer_four()
# Out:
# ['Captain',
#  'Pequod',
#  'Queequeg',
#  'Starbuck',
#  'almost',
#  'before',
#  'himself',
#  'little',
#  'seemed',
#  'should',
#  'though',
#  'through',
#  'whales',
#  'without']

# %% [markdown]
# ### Question 5
#
# Find the longest word in text1 and that word's length.
#
# *This function should return a tuple `(longest_word, length)`.*

# %%
def answer_five():
    
    alist = list(set(text1))
    
    res = max(alist, key=len)
    
    return res,len(res)

answer_five()
# Out:
# ("twelve-o'clock-at-night", 23)

# %% [markdown]
# ### Question 6
#
# What unique words have a frequency of more than 2000? What is their frequency?
#
# "Hint:  you may want to use `isalpha()` to check if the token is a word and not punctuation."
#
# *This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
def answer_six():
    
    liste = (nltk.word_tokenize(moby_raw))
    xar = []
    res = FreqDist(liste)
    son  = {k: v for k, v in sorted(res.items(), key=lambda item: item[1], reverse = True)}
    
    for x in list(son):
        
        y= (son[x],x)
        
        if(son[x] > 2000 and x.isalpha()):
            xar.append(y)
        
    
    return xar
answer_six()
# Out:
# [(13715, 'the'),
#  (6513, 'of'),
#  (6010, 'and'),
#  (4545, 'a'),
#  (4515, 'to'),
#  (3908, 'in'),
#  (2978, 'that'),
#  (2459, 'his'),
#  (2196, 'it'),
#  (2113, 'I')]

# %% [markdown]
# ### Question 7
#
# What is the average number of tokens per sentence?
#
# *This function should return a float.*

# %%
def answer_seven():
   
    
    tok = len((nltk.word_tokenize(moby_raw)))
    sen = len(nltk.sent_tokenize(moby_raw))
    
    return tok/sen

answer_seven()
# Out:
# 25.886926512383273

# %% [markdown]
# ### Question 8
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
#
# *This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
def answer_eight():
    
    liste = []
    toked = nltk.word_tokenize(moby_raw)
    pos = nltk.pos_tag(toked)
    for x in pos:
        liste.append(x[1])
        
    res = FreqDist(liste)
    
    son  = sorted(res.items(), key=lambda item: item[1], reverse = True)

    
    return son[:5]

answer_eight()
# Out:
# [('NN', 32729), ('IN', 28663), ('DT', 25879), (',', 19204), ('JJ', 17613)]

# %% [markdown]
# ## Part 2 - Spelling Recommender
#
# For this part of the assignment you will create three different spelling recommenders, that each take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest distance*, and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# *Each of the three different recommenders will use a different distance measure (outlined below).
#
# Each of the recommenders should provide recommendations for the three default words provided: `['cormulent', 'incendenece', 'validrate']`.

# %%
from nltk.corpus import words

correct_spellings = words.words()

# %% [markdown]
# ### Question 9
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the trigrams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_nine(entries=['cormulent', 'incendenece', 'validrate']):
    import pandas
    from nltk.util import ngrams
    liste = []
    corrects = pandas.Series(correct_spellings)
    correct = corrects[corrects.str.startswith(entries[0][0])]
    
    
                   
    jd = ((nltk.jaccard_distance(set(ngrams(entries[0], 3)), set(ngrams(word, 3))), word)
          for word in correct)
        
    closest = min(jd)
    liste.append(closest[1])
    
    correct = corrects[corrects.str.startswith(entries[1][0])]
    
    jd = ((nltk.jaccard_distance(set(ngrams(entries[1], 3)), set(ngrams(word, 3))), word)
          for word in correct)
        
    closest = min(jd)
    liste.append(closest[1])
    
    correct = corrects[corrects.str.startswith(entries[2][0])]
    
    jd = ((nltk.jaccard_distance(set(ngrams(entries[2], 3)), set(ngrams(word, 3))), word)
          for word in correct)
        
    closest = min(jd)
    liste.append(closest[1])
    
    
    
    return liste
    
answer_nine()
# Out:
# ['corpulent', 'indecence', 'validate']

# %% [markdown]
# ### Question 10
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Jaccard distance](https://en.wikipedia.org/wiki/Jaccard_index) on the 4-grams of the two words.**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_ten(entries=['cormulent', 'incendenece', 'validrate']):
    import pandas
    from nltk.util import ngrams
    liste = []
    corrects = pandas.Series(correct_spellings)
    correct = corrects[corrects.str.startswith(entries[0][0])]
                   
    jd = ((nltk.jaccard_distance(set(ngrams(entries[0], 4)), set(ngrams(word, 4))), word)
          for word in correct)
        
    closest = min(jd)
    liste.append(closest[1])
    
    
    correct = corrects[corrects.str.startswith(entries[1][0])]
    
    jd = ((nltk.jaccard_distance(set(ngrams(entries[1], 4)), set(ngrams(word, 4))), word)
          for word in correct)
        
    closest = min(jd)
    liste.append(closest[1])
    
    correct = corrects[corrects.str.startswith(entries[2][0])]
    
    jd = ((nltk.jaccard_distance(set(ngrams(entries[2], 4)), set(ngrams(word, 4))), word)
          for word in correct)
        
    closest = min(jd)
    liste.append(closest[1])
    
    
    
    return liste
    
answer_ten()
# Out:
# ['cormus', 'incendiary', 'valid']

# %% [markdown]
# ### Question 11
#
# For this recommender, your function should provide recommendations for the three default words provided above using the following distance metric:
#
# **[Edit distance on the two words with transpositions.](https://en.wikipedia.org/wiki/Damerau%E2%80%93Levenshtein_distance)**
#
# *This function should return a list of length three:
# `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
def answer_eleven(entries=['cormulent', 'incendenece', 'validrate']):
    
    import pandas
    from nltk.util import ngrams
    liste = []
    new = []
    corrects = pandas.Series(correct_spellings)
    correct = corrects[corrects.str.startswith(entries[0][0])]
    
    
    for word in correct:     
        jd = nltk.binary_distance(entries[0], word)
        x = word , jd
        
        liste.append(x)
    closest = max(liste) 
    new.append(closest[0])
    
    corrects = pandas.Series(correct_spellings)
    correct = corrects[corrects.str.startswith(entries[1][0])]
    
    
    for word in correct:     
        jd = nltk.binary_distance(entries[1], word)
        x = word , jd
        
        liste.append(x)
    closest = max(liste) 
    new.append(closest[0])
    
    corrects = pandas.Series(correct_spellings)
    correct = corrects[corrects.str.startswith(entries[2][0])]
    
    
    for word in correct:     
        jd = nltk.binary_distance(entries[2], word)
        x = word , jd
        
        liste.append(x)
    closest = max(liste) 
    new.append(closest[0])
    
    print(len(liste))
    
    return liste
    
answer_eleven()
# Out:
# 28880
# [('c', 1.0),
#  ('ca', 1.0),
#  ('caam', 1.0),
#  ('caama', 1.0),
#  ('caaming', 1.0),
#  ('caapeba', 1.0),
#  ('caatinga', 1.0),
#  ('cab', 1.0),
#  ('caba', 1.0),
#  ('cabaan', 1.0),
#  ('caback', 1.0),
#  ('cabaho', 1.0),
#  ('cabal', 1.0),
#  ('cabala', 1.0),
#  ('cabalassou', 1.0),
#  ('cabaletta', 1.0),
#  ('cabalic', 1.0),
#  ('cabalism', 1.0),
#  ('cabalist', 1.0),
#  ('cabalistic', 1.0),
#  ('cabalistical', 1.0),
#  ('cabalistically', 1.0),
#  ('caballer', 1.0),
#  ('caballine', 1.0),
#  ('caban', 1.0),
#  ('cabana', 1.0),
#  ('cabaret', 1.0),
#  ('cabas', 1.0),
#  ('cabasset', 1.0),
#  ('cabassou', 1.0),
#  ('cabbage', 1.0),
#  ('cabbagehead', 1.0),
#  ('cabbagewood', 1.0),
#  ('cabbagy', 1.0),
#  ('cabber', 1.0),
#  ('cabble', 1.0),
#  ('cabbler', 1.0),
#  ('cabby', 1.0),
#  ('cabda', 1.0),
#  ('cabdriver', 1.0),
#  ('cabdriving', 1.0),
#  ('cabellerote', 1.0),
#  ('caber', 1.0),
#  ('cabernet', 1.0),
#  ('cabestro', 1.0),
#  ('cabezon', 1.0),
# ...
